# %%
import pandas as pd
import requests
from urllib.request import urlopen
import scraping as s

# %%
df = s.join()
# Out:
# 362
# 362

# %%
df[['W', 'L']] = df['RECORD'].str.split('-', expand=True)

# %%
df = df.reset_index()

# %%
pd.set_option('display.max_columns', None)
df
# Out:
#                        TEAM   RK  CONF RECORD       ADJOE       ADJDE  \
# 0               Connecticut    1    BE   37-3  127.965556   91.271096
# 1                   Houston    2   B12   32-5  119.642151   86.480420
# 2                    Purdue    3   B10   34-5  126.019640   94.461318
# 3                    Auburn    4   SEC   27-8  121.011031   93.072294
# 4                  Iowa St.    5   B12   29-8  113.611714   87.668978
# ..                      ...  ...   ...    ...         ...         ...
# 357                     VMI  358    SC   4-28   87.943119  110.818640
# 358                   IUPUI  359  Horz   6-26   92.718024  117.159205
# 359          St. Francis PA  360   NEC   8-22   93.467555  118.121211
# 360              Coppin St.  361  MEAC   2-27   85.344914  111.305673
# 361  Mississippi Valley St.  362  SWAC   1-30   85.932392  115.871169
#
#       BARTHAG        WAB       ADJT  EFG_O  EFG_D   FTR  FTRD   ORB   DRB  \
# ...

# %%
df.set_index('TEAM', inplace=True)

# %%
df.to_csv('/Users/isaacanderson/Desktop/CSE314/MarchMadness/data/ncaa2024')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df.to_csv('/Users/isaacanderson/Desktop/CSE314/MarchMadness/data/ncaa2024')
#
# File ~/anaconda3/envs/boo/lib/python3.12/site-packages/pandas/util/_decorators.py:333, in wrapper(*args, **kwargs)
#     325         warnings.warn(
#     326             msg.format(arguments=_format_argument_list(allow_args)),
#     327             FutureWarning,
#     328             stacklevel=find_stack_level(),
#     329         )
#     330     return func(*args, **kwargs)
#     332 # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
# --> 333 # attribute "__signature__"
#     334 wrapper.__signature__ = new_sig  # type: ignore[attr-defined]
#     335 return wrapper
#
# ...
